# %% [markdown]
# # **Assignment \#4**: Machine Learning MC886/MO444
# University of Campinas (UNICAMP), Institute of Computing (IC)
#
# Prof. Sandra Avila, 2022s2

# %%
# TODO: RA & Name 
print('RA1: ' + 'Full_Name_1')
print('RA2: ' + 'Full_Name_2')
# Out:
# RA1: Full_Name_1
# RA2: Full_Name_2

# %% [markdown]
# ## Objective
#
# Exploring **unsupervised learning techniques** by using dimensionality reduction techniques.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import torch
import tensorflow as tf
from tensorflow.python import keras
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras import layers, models
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical 
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## Dataset
#
# Fashion-MNIST is a dataset of Zalando’s article images, consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28×28 grayscale image, associated with a label from 10 classes.
#
# Dataset Information:
#
# - You should respect the following traininig/test split: 60,000 training examples, and 10,000 test examples. Avoid overfitting.
#
# - The data is available at:
# https://www.dropbox.com/s/qawunrav8ri0sp4/fashion-mnist-dataset.zip:
# ‘train’ folder (fashion-mnist train.csv.zip) + ‘test’ folder (fashion-mnist test.csv.zip).
#
#   - You can also download the data by the framework you are using.
#
# - Each training and test example is assigned to one of the following labels: 0 t-shirt/top, 1 trouser, 2 pullover, 3 dress, 4 coat, 5 sandal, 6 shirt, 7 sneaker, 8 bag, 9 ankle boot.
# - Each row is a separate image. Column 1 is the class label. The remaining columns are pixel numbers (784 total). Each value is the darkness of the pixel (1 to 255). Dataset was converted to CSV with this script: https://pjreddie.com/projects/mnist-in-csv.

# %%
# Download Fashion-MNIST
train, test = pd.read_csv('fashion-mnist_train.csv'), pd.read_csv('fashion-mnist_test.csv')

x_train, x_val, y_train, y_val = train_test_split(
    train.loc[:, train.columns!='label'], train.loc[:, train.columns=='label'], 
    test_size = 0.3, random_state= 10
)

# %%
x_train.shape, x_val.shape
# Out:
# ((42000, 784), (18000, 784))

# %%
# Plot a data grid for general observation

figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(x_train.to_numpy().reshape(-1, 28, 28, 1) ), size=(1,)).item()
    img = x_train.to_numpy().reshape(-1, 28, 28, 1) [sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_values = x_train_scaled.reshape(-1, 28, 28, 1) 
x_val_values = x_val_scaled.reshape(-1,28,28,1)
x_test_values = x_test_scaled.reshape(-1,28,28,1)

x_train_values.shape, x_val_values.shape, x_test_values.shape
# Out:
# ((42000, 28, 28, 1), (18000, 28, 28, 1), (10000, 28, 28, 1))

# %%
y_train = to_categorical(y_train, num_classes=10)
y_val = to_categorical(y_val, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

y_train.shape, y_val.shape, y_test.shape
# Out:
# ((42000, 10), (18000, 10), (10000, 10))

# %% [markdown]
# ### Activities
#
# 1. (2 points) Baseline: Explore Convolutional Neural Networks with Fashion-MNIST. What is the accuracy of your CNN model? (1.5 points) Describe your Convolutional Neural Network architecture. (0.5 points) What are your conclusions about the baseline?

# %%
# Set the parameters of the neural network
bs_model = Sequential()

loss_function = 'categorical_crossentropy'
opt = 'adam'

# %%
# Create your convolutional neural network architecture

bs_model.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)))
bs_model.add(layers.MaxPooling2D((2,2)))
bs_model.add(layers.Conv2D(64, (3,3), activation='relu'))
bs_model.add(layers.MaxPooling2D((2,2)))
bs_model.add(layers.Flatten())
bs_model.add(layers.Dense(54, activation='relu'))
bs_model.add(layers.Dense(10, activation='softmax'))

# %%
bs_model.compile(
    optimizer = opt, 
    loss = loss_function, 
    metrics = ['accuracy']
)

# %%
bs_hist = bs_model.fit(x_train_values, y_train, epochs=10,
                       validation_data = (x_val_values, y_val))
# Out:
# Epoch 1/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.4737 - accuracy: 0.8296 - val_loss: 0.3650 - val_accuracy: 0.8649
# Epoch 2/10
# 1313/1313 [==============================] - 18s 13ms/step - loss: 0.3154 - accuracy: 0.8861 - val_loss: 0.3022 - val_accuracy: 0.8896
# Epoch 3/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.2684 - accuracy: 0.9021 - val_loss: 0.2792 - val_accuracy: 0.8980
# Epoch 4/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.2299 - accuracy: 0.9162 - val_loss: 0.2757 - val_accuracy: 0.9017
# Epoch 5/10
# 1313/1313 [==============================] - 16s 13ms/step - loss: 0.2008 - accuracy: 0.9255 - val_loss: 0.2892 - val_accuracy: 0.8995
# Epoch 6/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.1783 - accuracy: 0.9326 - val_loss: 0.2894 - val_accuracy: 0.9003
# Epoch 7/10
# 1313/1313 [==============================] - 16s 13ms/step - loss: 0.1553 - accuracy: 0.9412 - val_loss: 0.2825 - val_accuracy: 0.9042
# Epoch 8/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.1367 - accuracy: 0.9482 - val_loss: 0.2833 - val_accuracy: 0.9059
# Epoch 9/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.1194 - accuracy: 0.9548 - val_loss: 0.3252 - val_accuracy: 0.9049
# Epoch 10/10
# 1313/1313 [==============================] - 17s 13ms/step - loss: 0.1035 - accuracy: 0.9616 - val_loss: 0.3538 - val_accuracy: 0.9012

# %%
# Report your accuracy using convolutional neural network

plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.plot(bs_hist.history['loss'], color='red', label='Train-Loss')
plt.plot(bs_hist.history['val_loss'], color='green', label='Val-Loss')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.plot(bs_hist.history['accuracy'], color='red', label='Train-Accuracy')
plt.plot(bs_hist.history['val_accuracy'], color='green', label='Val-Accuracy')
plt.legend(loc='best')
plt.show()

# %%
# What are your conclusions about the baseline?

# %% [markdown]
# **Resp.:** Inicialmente, as variáveis que representam os **pixels** foram normalizadas (com base em uma normal padrão), o que facilitou o uso, posteriormente, nas componentes principais. No modelo **baseline** foi utilizado o otimizador Adam para se obter os parâmetros da rede neural convolucional (CNN), com inicialmente, 32 filtros com **kernel** $3 \times 3$, posteriormente, acrescentou-se um **Max Pooling** $2 \times 2$ . Por último, acrescentou-se mais 64 filtros com **kernel** $3 \times 3$ e, novamente, um max Pooling $2 \times 2$. Todas as funções de ativação utilizadas foram a ReLU, exceto na camada de **output**, a qual foi empregada a **Softmax**.
#
#   O desempenho do **baseline** já foi surpreendente, com uma acurácia acima dos $88\%$. Analisando o gráfico da função **Loss** pelo número de épocas, notou-se que o ideal para este modelo é um número de épocas igual a $2$, pois, após esse valor, não há ganhos significativos na acurácia em relação ao conjunto de validação e sinais de **overfitting** poderam ser notados com o aumento da **Loss**.

# %% [markdown]
# 2. (2 points) Using PCA: Re-do the first experiment considering the PCA dimensionality reduction. (1.5 points) Consider two different energies (variance) for reducing the image dimensionality. (0.5 points) What are the conclusions when using PCA in this problem? Does the accuracy improve?

# %%
# Run PCA methods

pca225 = PCA(n_components=225)
x_train_pca225 = pca225.fit(x_train_scaled).transform(x_train_scaled)
x_val_pca225 = pca225.transform(x_val_scaled)

# %%
variab_top225 = pca225.explained_variance_ratio_

pca225_values = {
    'Componente':np.arange(pca225.n_components_) + 1,
    'Variab Explicada':variab_top225,
    'Variab Acumulada':np.cumsum(variab_top225)
}

# %%
pd.DataFrame(pca225_values).head(30)
# Out:
#     Componente  Variab Explicada  Variab Acumulada
# 0            1          0.221123          0.221123
# 1            2          0.143661          0.364785
# 2            3          0.054422          0.419206
# 3            4          0.051084          0.470291
# 4            5          0.040501          0.510791
# 5            6          0.030201          0.540992
# 6            7          0.027494          0.568486
# 7            8          0.023480          0.591966
# 8            9          0.016796          0.608763
# 9           10          0.013132          0.621895
# 10          11          0.011573          0.633468
# 11          12          0.009587          0.643054
# 12          13          0.008819          0.651873
# 13          14          0.008668          0.660541
# 14          15          0.007468          0.668009
# 15          16          0.007292          0.675301
# 16          17          0.006572          0.681874
# 17          18          0.006312          0.688186
# 18          19          0.006205          0.694392
# 19          20          0.005805          0.700197
# 20          21          0.005168          0.705365
# 21          22          0.005047          0.710412
# 22          23          0.004762          0.715174
# 23          24          0.004526          0.719700
# 24          25          0.004424          0.724125
# 25          26          0.004193          0.728317
# 26          27          0.003969          0.732286
# 27          28          0.003909          0.736195
# 28          29          0.003785          0.739980
# 29          30          0.003745          0.743725

# %%
pd.DataFrame(pca225_values).tail(30)
# Out:
#      Componente  Variab Explicada  Variab Acumulada
# 195         196          0.000389          0.930575
# 196         197          0.000387          0.930962
# 197         198          0.000385          0.931347
# 198         199          0.000380          0.931727
# 199         200          0.000377          0.932105
# 200         201          0.000375          0.932480
# 201         202          0.000373          0.932853
# 202         203          0.000370          0.933223
# 203         204          0.000365          0.933588
# 204         205          0.000362          0.933951
# 205         206          0.000357          0.934308
# 206         207          0.000354          0.934662
# 207         208          0.000350          0.935012
# 208         209          0.000345          0.935357
# 209         210          0.000344          0.935701
# 210         211          0.000343          0.936044
# 211         212          0.000342          0.936385
# 212         213          0.000337          0.936723
# 213         214          0.000335          0.937058
# 214         215          0.000335          0.937393
# 215         216          0.000330          0.937723
# 216         217          0.000325          0.938047
# 217         218          0.000323          0.938370
# 218         219          0.000319          0.938689
# 219         220          0.000317          0.939006
# 220         221          0.000315          0.939321
# 221         222          0.000310          0.939631
# 222         223          0.000306          0.939937
# 223         224          0.000305          0.940242
# 224         225          0.000303          0.940544

# %%
PC225_values = np.arange(pca225.n_components_) + 1
plt.figure(figsize=(12,8))
plt.plot(PC225_values, pca225.explained_variance_ratio_, 'ro-', linewidth=1)
plt.title('Scree Plot')
plt.xlabel('Componentes Principais')
plt.ylabel('Proporção da Variabilidade Explicada')
plt.show()

# %%
x_train_pca225.shape, x_val_pca225.shape
# Out:
# ((42000, 225), (18000, 225))

# %%
x_train_pca225_values = x_train_pca225.reshape(-1,15,15,1)
x_val_pca225_values = x_val_pca225.reshape(-1,15,15,1)

x_train_pca225_values.shape, x_val_pca225_values.shape
# Out:
# ((42000, 15, 15, 1), (18000, 15, 15, 1))

# %%
m1_pca = Sequential()

m1_pca.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(15,15,1)))
m1_pca.add(layers.MaxPooling2D((2,2)))
m1_pca.add(layers.Conv2D(64, (3,3), activation='relu'))
m1_pca.add(layers.MaxPooling2D((2,2)))
m1_pca.add(layers.Flatten())
m1_pca.add(layers.Dense(54, activation='relu'))
m1_pca.add(layers.Dense(10, activation='softmax'))

# %%
m1_pca.compile(
    optimizer = opt, 
    loss = loss_function, 
    metrics = ['accuracy']
)

# %%
m1_pca_hist = m1_pca.fit(x_train_pca225_values, y_train, epochs=20,
                       validation_data = (x_val_pca225_values, y_val))
# Out:
# Epoch 1/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.6952 - accuracy: 0.7609 - val_loss: 0.4920 - val_accuracy: 0.8259
# Epoch 2/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.4603 - accuracy: 0.8355 - val_loss: 0.4549 - val_accuracy: 0.8343
# Epoch 3/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.4141 - accuracy: 0.8513 - val_loss: 0.4349 - val_accuracy: 0.8456
# Epoch 4/20
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.3797 - accuracy: 0.8628 - val_loss: 0.4080 - val_accuracy: 0.8537
# Epoch 5/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3572 - accuracy: 0.8697 - val_loss: 0.4138 - val_accuracy: 0.8525
# Epoch 6/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3356 - accuracy: 0.8771 - val_loss: 0.4052 - val_accuracy: 0.8538
# Epoch 7/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3216 - accuracy: 0.8825 - val_loss: 0.4030 - val_accuracy: 0.8577
# Epoch 8/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3035 - accuracy: 0.8890 - val_loss: 0.3984 - val_accuracy: 0.8597
# Epoch 9/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2840 - accuracy: 0.8947 - val_loss: 0.4491 - val_accuracy: 0.8525
# Epoch 10/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2757 - accuracy: 0.8994 - val_loss: 0.4075 - val_accuracy: 0.8610
# Epoch 11/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2554 - accuracy: 0.9043 - val_loss: 0.4383 - val_accuracy: 0.8597
# Epoch 12/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2479 - accuracy: 0.9090 - val_loss: 0.4360 - val_accuracy: 0.8553
# Epoch 13/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2380 - accuracy: 0.9120 - val_loss: 0.4851 - val_accuracy: 0.8481
# Epoch 14/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2284 - accuracy: 0.9152 - val_loss: 0.4670 - val_accuracy: 0.8538
# Epoch 15/20
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.2189 - accuracy: 0.9193 - val_loss: 0.4794 - val_accuracy: 0.8547
# Epoch 16/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2058 - accuracy: 0.9235 - val_loss: 0.4937 - val_accuracy: 0.8557
# Epoch 17/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1962 - accuracy: 0.9285 - val_loss: 0.4943 - val_accuracy: 0.8529
# Epoch 18/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1859 - accuracy: 0.9304 - val_loss: 0.4937 - val_accuracy: 0.8537
# Epoch 19/20
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1775 - accuracy: 0.9340 - val_loss: 0.5304 - val_accuracy: 0.8562
# Epoch 20/20
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1702 - accuracy: 0.9352 - val_loss: 0.5586 - val_accuracy: 0.8502

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.plot(m1_pca_hist.history['loss'], color='red', label='Train-Loss')
plt.plot(m1_pca_hist.history['val_loss'], color='green', label='Val-Loss')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.plot(m1_pca_hist.history['accuracy'], color='red', label='Train-Accuracy')
plt.plot(m1_pca_hist.history['val_accuracy'], color='green', label='Val-Accuracy')
plt.legend(loc='best')
plt.show()

# %%
pca625 = PCA(n_components=625)
x_train_pca625 = pca625.fit(x_train_scaled).transform(x_train_scaled)
x_val_pca625 = pca625.transform(x_val_scaled)

# %%
variab_top625 = pca625.explained_variance_ratio_

pca625_values = {
    'Componente':np.arange(pca625.n_components_) + 1,
    'Variab Explicada':variab_top625,
    'Variab Acumulada':np.cumsum(variab_top625)
}

# %%
pd.DataFrame(pca625_values).tail(30)
# Out:
#      Componente  Variab Explicada  Variab Acumulada
# 595         596          0.000050          0.994383
# 596         597          0.000050          0.994434
# 597         598          0.000050          0.994483
# 598         599          0.000049          0.994533
# 599         600          0.000049          0.994582
# 600         601          0.000048          0.994630
# 601         602          0.000048          0.994678
# 602         603          0.000048          0.994726
# 603         604          0.000048          0.994774
# 604         605          0.000047          0.994821
# 605         606          0.000047          0.994868
# 606         607          0.000047          0.994915
# 607         608          0.000046          0.994961
# 608         609          0.000046          0.995007
# 609         610          0.000045          0.995052
# 610         611          0.000045          0.995098
# 611         612          0.000045          0.995143
# 612         613          0.000045          0.995188
# 613         614          0.000045          0.995232
# 614         615          0.000044          0.995277
# 615         616          0.000044          0.995321
# 616         617          0.000043          0.995364
# 617         618          0.000043          0.995408
# 618         619          0.000043          0.995450
# 619         620          0.000043          0.995493
# 620         621          0.000042          0.995535
# 621         622          0.000042          0.995577
# 622         623          0.000042          0.995619
# 623         624          0.000041          0.995660
# 624         625          0.000041          0.995700

# %%
PC625_values = np.arange(pca625.n_components_) + 1
plt.figure(figsize=(12,8))
plt.plot(PC625_values, pca625.explained_variance_ratio_, 'ro-', linewidth=1)
plt.title('Scree Plot')
plt.xlabel('Componentes Principais')
plt.ylabel('Proporção da Variabilidade Explicada')
plt.show()

# %%
x_train_pca625.shape, x_val_pca625.shape
# Out:
# ((42000, 625), (18000, 625))

# %%
x_train_pca625_values = x_train_pca625.reshape(-1,25,25,1)
x_val_pca625_values = x_val_pca625.reshape(-1,25,25,1)

x_train_pca625_values.shape, x_val_pca625_values.shape
# Out:
# ((42000, 25, 25, 1), (18000, 25, 25, 1))

# %%
m2_pca = Sequential()

m2_pca.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(25,25,1)))
m2_pca.add(layers.MaxPooling2D((2,2)))
m2_pca.add(layers.Conv2D(64, (3,3), activation='relu'))
m2_pca.add(layers.MaxPooling2D((2,2)))
m2_pca.add(layers.Flatten())
m2_pca.add(layers.Dense(54, activation='relu'))
m2_pca.add(layers.Dense(10, activation='softmax'))

# %%
m2_pca.compile(
    optimizer = opt, 
    loss = loss_function, 
    metrics = ['accuracy']
)

# %%
m2_pca_hist = m2_pca.fit(x_train_pca625_values, y_train, epochs=20,
                       validation_data = (x_val_pca625_values, y_val))
# Out:
# Epoch 1/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.6614 - accuracy: 0.7698 - val_loss: 0.4868 - val_accuracy: 0.8259
# Epoch 2/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.4386 - accuracy: 0.8423 - val_loss: 0.4644 - val_accuracy: 0.8369
# Epoch 3/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.3886 - accuracy: 0.8610 - val_loss: 0.4113 - val_accuracy: 0.8510
# Epoch 4/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.3468 - accuracy: 0.8747 - val_loss: 0.4163 - val_accuracy: 0.8543
# Epoch 5/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.3127 - accuracy: 0.8864 - val_loss: 0.4296 - val_accuracy: 0.8588
# Epoch 6/20
# 1313/1313 [==============================] - 13s 10ms/step - loss: 0.2865 - accuracy: 0.8957 - val_loss: 0.4173 - val_accuracy: 0.8589
# Epoch 7/20
# 1313/1313 [==============================] - 12s 10ms/step - loss: 0.2597 - accuracy: 0.9040 - val_loss: 0.4186 - val_accuracy: 0.8554
# Epoch 8/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.2361 - accuracy: 0.9128 - val_loss: 0.4684 - val_accuracy: 0.8545
# Epoch 9/20
# 1313/1313 [==============================] - 14s 10ms/step - loss: 0.2174 - accuracy: 0.9200 - val_loss: 0.4435 - val_accuracy: 0.8587
# Epoch 10/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.1953 - accuracy: 0.9280 - val_loss: 0.4993 - val_accuracy: 0.8491
# Epoch 11/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.1830 - accuracy: 0.9330 - val_loss: 0.4848 - val_accuracy: 0.8558
# Epoch 12/20
# 1313/1313 [==============================] - 14s 11ms/step - loss: 0.1652 - accuracy: 0.9371 - val_loss: 0.5063 - val_accuracy: 0.8528
# Epoch 13/20
# 1313/1313 [==============================] - 14s 11ms/step - loss: 0.1510 - accuracy: 0.9433 - val_loss: 0.5517 - val_accuracy: 0.8524
# Epoch 14/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.1360 - accuracy: 0.9490 - val_loss: 0.6290 - val_accuracy: 0.8453
# Epoch 15/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.1257 - accuracy: 0.9535 - val_loss: 0.6430 - val_accuracy: 0.8509
# Epoch 16/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.1128 - accuracy: 0.9579 - val_loss: 0.6991 - val_accuracy: 0.8494
# Epoch 17/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.1120 - accuracy: 0.9591 - val_loss: 0.7162 - val_accuracy: 0.8435
# Epoch 18/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.0974 - accuracy: 0.9642 - val_loss: 0.7068 - val_accuracy: 0.8459
# Epoch 19/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.0869 - accuracy: 0.9691 - val_loss: 0.7393 - val_accuracy: 0.8501
# Epoch 20/20
# 1313/1313 [==============================] - 12s 9ms/step - loss: 0.0892 - accuracy: 0.9679 - val_loss: 0.7914 - val_accuracy: 0.8453

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.plot(m2_pca_hist.history['loss'], color='red', label='Train-Loss')
plt.plot(m2_pca_hist.history['val_loss'], color='green', label='Val-Loss')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.plot(m2_pca_hist.history['accuracy'], color='red', label='Train-Accuracy')
plt.plot(m2_pca_hist.history['val_accuracy'], color='green', label='Val-Accuracy')
plt.legend(loc='best')
plt.show()

# %%
# Re-do the first experiment considering the PCA dimensionality reduction

# %% [markdown]
# **Comentários :** Realizou-se duas abordagens com o emprego de componentes principais (PCA): ora com 225 componentes e ora com 625. Notou-se que com 225 componentes, a variabilidade dos dados explicada foi muito satisfatória (aproximadamente, $94\%$), enquanto com 625 esse valor melhorou ainda mais (aproximadamente, $99\%$). No entanto, comparando-se a acurácia no conjunto de validação dessas duas abordagens de emprego das PCA,  não houve muita diferença, ambos aprensentando uma acurácia de $85\%$, aproximadamente. Além disso, foi observado que, com base no gráfico da **Loss**, a abordagem com um maior número de PCA (625) tem um potencial de **overfitting** maior conforme o aumento do número de épocas.
#
# Por fim, comparando as duas abordagens com o experimento da questão anterior, i.e, sem o emprego das componentes principais, **o primeiro** experimento apresentou uma melhor acurácia, no entanto, com um custo computacional bem mais alto. Portanto, com base nessas duas abordagens, não houve uma melhora na acurácia do modelo ao se usar as componentes.

# %% [markdown]
# 3. (0.5 point) What can we infer when analyzing the breakdown of data into components using a chart to plot the data in 2-dimensional space to view separation?

# %%
# In order to see how the PCA components are separating out the digits, lets use the following method, plot_components, to plot the data in a 2 dimensional space to view separation.
# The input parameters are the PCA fit in X and the labels
def plot_components(X, y):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)
    plt.figure(figsize=(10, 6))
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(y[i]), 
                 color=plt.cm.Set1(y[i]), 
                 fontdict={'size': 15})

    plt.xticks([]), plt.yticks([]), plt.ylim([-0.1,1.1]), plt.xlim([-0.1,1.1])

# %%
pca2 = PCA(n_components=2)
x_train_pca2 = pca2.fit(x_train_scaled).transform(x_train_scaled)

# %%
y_train_label = np.argmax(y_train, axis=1)

# %%
# The input parameters are the PCA fit in X and the labels
plot_components(x_train_pca2, y_train_label)

# %% [markdown]
# **Comentários:** Observando o biplot, notou-se que as duas componentes principais criam dois subespaços alternativos às diversas dimensões representadas pelos **pixels**. Nesses novos dois eixos de coordenadas, é possível observar que há regiões de conglomeração (agrupamentos) de cada uma das categorias da variável **target**, algumas bem definidas, enquanto outras se sobrepõe tornando-as difíceis de diferenciá-las de algumas outras categorias. Essa dificuldade de indificação em um biplot é devido à baixa variabilidade explicada por apenas duas componentes (aproximadamente, $36\%$).

# %% [markdown]
# 4. (2 points) How many components are needed for a better evaluation of the model? Define the minimum and maximum components to be tested using the energies_number method. How can we evaluate this graph and the quantity that was defined as best for the problem?

# %%
def energies_number(min, max, x_train, x_valid, y_train, y_val):
    # Select a range of min and max number of dimensions, min/max.

    acc_list, acc_val_list, pc_list = [], [], []
    for pc in range(min,max):
        bs_model = Sequential()
        loss_function = 'categorical_crossentropy'
        opt = 'adam'
        
        bs_model.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(pc,pc,1)))
        bs_model.add(layers.MaxPooling2D((2,2)))
        bs_model.add(layers.Conv2D(64, (3,3), activation='relu'))
        bs_model.add(layers.MaxPooling2D((2,2)))
        bs_model.add(layers.Flatten())
        bs_model.add(layers.Dense(54, activation='relu'))
        bs_model.add(layers.Dense(10, activation='softmax'))
        
        bs_model.compile(
            optimizer = opt, 
            loss = loss_function, 
            metrics = ['accuracy'])

        pca = PCA(n_components = pc**2)
        
        x_train_pca = pca.fit(x_train).transform(x_train)
        x_val_pca = pca.transform(x_valid)
        
        x_train_pca_values = x_train_pca.reshape(-1, pc, pc, 1)
        x_val_pca_values = x_val_pca.reshape(-1, pc, pc, 1)
        
        pca_hist = bs_model.fit(x_train_pca_values, y_train, epochs = 2,
                       validation_data = (x_val_pca_values, y_val))
        
        acc_val = np.max(pca_hist.history['val_accuracy'])
        acc = pca_hist.history['accuracy'][pca_hist.history['val_accuracy'].index(np.max(pca_hist.history['val_accuracy']))]
        acc_list.append(acc)
        acc_val_list.append(acc_val)
        pc_list.append(pc)
    return acc_list, acc_val_list, pc_list

# %%
acc_list, acc_val_list, pc_list = energies_number(10, 25, x_train_scaled, x_val_scaled, y_train, y_val)
# Out:
# Epoch 1/2
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.6725 - accuracy: 0.7666 - val_loss: 0.4894 - val_accuracy: 0.8279
# Epoch 2/2
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.4689 - accuracy: 0.8316 - val_loss: 0.4454 - val_accuracy: 0.8382
# Epoch 1/2
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.6684 - accuracy: 0.7699 - val_loss: 0.4787 - val_accuracy: 0.8323
# Epoch 2/2
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.4706 - accuracy: 0.8304 - val_loss: 0.4640 - val_accuracy: 0.8381
# Epoch 1/2
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.6873 - accuracy: 0.7667 - val_loss: 0.5412 - val_accuracy: 0.8121
# Epoch 2/2
# 1313/1313 [==============================] - 2s 2ms/step - loss: 0.4772 - accuracy: 0.8291 - val_loss: 0.4896 - val_accuracy: 0.8205
# Epoch 1/2
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.6887 - accuracy: 0.7617 - val_loss: 0.5202 - val_accuracy: 0.8151
# Epoch 2/2
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.4721 - accuracy: 0.8324 - val_loss: 0.4553 - val_accuracy: 0.8363
# Epoch 1/2
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.6864 - accuracy: 0.7649 - val_loss: 0.5519 - val_accuracy: 0.8043
# Epoch 2/2
# 1313/1313 [==============================] - 3s 3ms/step - loss: 0.4640 - accuracy: 0.8361 - val_loss: 0.4290 - val_accuracy: 0.8463
# Epoch 1/2
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.6828 - accuracy: 0.7635 - val_loss: 0.5406 - val_accuracy: 0.8108
# Epoch 2/2
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.4635 - accuracy: 0.8346 - val_loss: 0.4305 - val_accuracy: 0.8469
# Epoch 1/2
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.6955 - accuracy: 0.7565 - val_loss: 0.5146 - val_accuracy: 0.8233
# Epoch 2/2
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.4637 - accuracy: 0.8359 - val_loss: 0.4452 - val_accuracy: 0.8407
# Epoch 1/2
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.6781 - accuracy: 0.7636 - val_loss: 0.5122 - val_accuracy: 0.8112
# Epoch 2/2
# 1313/1313 [==============================] - 7s 5ms/step - loss: 0.4657 - accuracy: 0.8331 - val_loss: 0.4605 - val_accuracy: 0.8371
# Epoch 1/2
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.6810 - accuracy: 0.7615 - val_loss: 0.4868 - val_accuracy: 0.8230
# Epoch 2/2
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.4479 - accuracy: 0.8380 - val_loss: 0.4540 - val_accuracy: 0.8399
# Epoch 1/2
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.6791 - accuracy: 0.7607 - val_loss: 0.4961 - val_accuracy: 0.8231
# Epoch 2/2
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.4456 - accuracy: 0.8373 - val_loss: 0.4509 - val_accuracy: 0.8367
# Epoch 1/2
# 1313/1313 [==============================] - 6s 5ms/step - loss: 0.6868 - accuracy: 0.7628 - val_loss: 0.4964 - val_accuracy: 0.8186
# Epoch 2/2
# 1313/1313 [==============================] - 6s 5ms/step - loss: 0.4578 - accuracy: 0.8369 - val_loss: 0.4701 - val_accuracy: 0.8306
# Epoch 1/2
# 1313/1313 [==============================] - 10s 7ms/step - loss: 0.6773 - accuracy: 0.7662 - val_loss: 0.5255 - val_accuracy: 0.8086
# Epoch 2/2
# 1313/1313 [==============================] - 9s 7ms/step - loss: 0.4451 - accuracy: 0.8380 - val_loss: 0.4451 - val_accuracy: 0.8409
# Epoch 1/2
# 1313/1313 [==============================] - 11s 8ms/step - loss: 0.6752 - accuracy: 0.7669 - val_loss: 0.4861 - val_accuracy: 0.8311
# Epoch 2/2
# 1313/1313 [==============================] - 10s 8ms/step - loss: 0.4474 - accuracy: 0.8407 - val_loss: 0.4270 - val_accuracy: 0.8493
# Epoch 1/2
# 1313/1313 [==============================] - 11s 8ms/step - loss: 0.6891 - accuracy: 0.7596 - val_loss: 0.4868 - val_accuracy: 0.8294
# Epoch 2/2
# 1313/1313 [==============================] - 11s 8ms/step - loss: 0.4457 - accuracy: 0.8407 - val_loss: 0.4388 - val_accuracy: 0.8452
# Epoch 1/2
# 1313/1313 [==============================] - 9s 7ms/step - loss: 0.6763 - accuracy: 0.7620 - val_loss: 0.5326 - val_accuracy: 0.8056
# Epoch 2/2
# 1313/1313 [==============================] - 9s 7ms/step - loss: 0.4457 - accuracy: 0.8392 - val_loss: 0.4307 - val_accuracy: 0.8472

# %%
plt.figure(figsize=(15,5))
plt.xlabel("Dimensions", fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.plot(acc_list, color='red', label='Train-Accuracy')
plt.plot(acc_val_list, color='green', label='Val-Accuracy')
plt.legend(loc='best')
xi = list(range(len(pc_list)))
plt.xticks(xi, pc_list)
plt.show()

# %%
print('The maximum accuracy attained is ',np.max(acc_val_list),'% with ', pc_list[acc_val_list.index(np.max(acc_val_list))],' dimensions. Beyond this peak, additional principal components appear to mostly contribute noise.')
# Out:
# The maximum accuracy attained is  0.8493333458900452 % with  22  dimensions. Beyond this peak, additional principal components appear to mostly contribute noise.

# %% [markdown]
# **Comentários:** Foram considerados valores para redução de dimensionalidade, valores que possuem raiz quadrada como numero inteiro para ajuste dos modelos.
#
# Dentre as possibilidades, foram consideradas potências de $10$ a $25$ $(10^2,11^2,...,25^2)$ como medidas de redução para componentes principais.
#
# Os modelos considerados respeitam a estrutura do baseline apresentado, sendo a unica variação o número de componentes. Levando esse fato em consideração, o desempenho dos modelos apresenta comportamentos bem semelhantes levando em consideração o grande intervalo de componentes principais considerados (100 - 625).
#
# Entretanto, o modelo com 22 dimensoes ($22^2=484$ componentes) teve o melhor desempenho e mesmo assim não foi superior ao baseline proposto.

# %% [markdown]
# 5. (3.5 points) Using Autoencoders: Re-do the first experiment (question 2) considering Autoencoders for reducing the image dimensionality. (3 points) Consider two different latent vector sizes for reducing the image dimensionality. (0.5 points) What are the conclusions when using Autoencoders in this problem? Does accuracy improve?
#
# Autoencoders are a branch of neural networks which attempt to compress the information of the input variables into a reduced dimensional space and then recreate the input data set. Typically the autoencoder is trained over some iterations using gradient descent, minimizing the mean squared error.
# The key component is the “bottleneck” hidden layer. This is where the information from the input has been compressed. By extracting this layer from the model, each node can be treated as a variable in the same way each chosen principal component is used in the following models.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create your AutoEncoder network architecture:
x_train = np.array(x_train).reshape(-1, 28, 28, 1) / 255.0
x_val = np.array(x_val).reshape(-1, 28, 28, 1) / 255.0

import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (2, 2), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(16, (2, 2), activation='relu', padding='same')(x)
x = layers.Conv2D(4, (2, 2), activation='relu', padding='same')(x)
x = layers.Conv2D(1, (2, 2), activation='relu', padding='same')(x)
x = layers.Flatten()(x)
encoded = layers.Dense(2, activation='relu')(x)


x = layers.Dense(4, activation='relu')(encoded)
x = layers.Reshape((2, 2, 1))(x)
x = layers.Conv2D(4, (2, 2), activation='relu', padding='same')(x)
x = layers.Conv2D(16, (2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((7, 7))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')

# %%
autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_val, x_val))
# Out:
# Epoch 1/5
# 165/165 [==============================] - 107s 631ms/step - loss: 0.4109 - accuracy: 0.4839 - val_loss: 0.8808 - val_accuracy: 0.5026
# Epoch 2/5
# 165/165 [==============================] - 106s 640ms/step - loss: 0.3634 - accuracy: 0.4933 - val_loss: 1.2876 - val_accuracy: 0.5026
# Epoch 3/5
# 165/165 [==============================] - 105s 638ms/step - loss: 0.3560 - accuracy: 0.4946 - val_loss: 0.5833 - val_accuracy: 0.5023
# Epoch 4/5
# 165/165 [==============================] - 104s 631ms/step - loss: 0.3497 - accuracy: 0.4955 - val_loss: 0.3842 - val_accuracy: 0.5006
# Epoch 5/5
# 165/165 [==============================] - 104s 629ms/step - loss: 0.3464 - accuracy: 0.4962 - val_loss: 0.3543 - val_accuracy: 0.4980

# %%
decoded_imgs_train = autoencoder.predict(x_train)
decoded_imgs_val = autoencoder.predict(x_val)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_val[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs_val[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1313/1313 [==============================] - 50s 38ms/step
# 563/563 [==============================] - 25s 45ms/step

# %%
bs_hist2 = bs_model.fit(decoded_imgs_train, y_train, epochs=10,
                       validation_data = (decoded_imgs_val, y_val))
# Out:
# Epoch 1/10
#    3/1313 [..............................] - ETA: 36s - loss: 2.2768 - accuracy: 0.2708
# C:\Users\bruno\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.9762 - accuracy: 0.6204 - val_loss: 0.9272 - val_accuracy: 0.6336
# Epoch 2/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.9044 - accuracy: 0.6444 - val_loss: 0.8971 - val_accuracy: 0.6481
# Epoch 3/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8917 - accuracy: 0.6472 - val_loss: 0.9031 - val_accuracy: 0.6481
# Epoch 4/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8849 - accuracy: 0.6518 - val_loss: 0.8988 - val_accuracy: 0.6412
# Epoch 5/10
# 1313/1313 [==============================] - 41s 32ms/step - loss: 0.8802 - accuracy: 0.6534 - val_loss: 0.8863 - val_accuracy: 0.6466
# Epoch 6/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8742 - accuracy: 0.6548 - val_loss: 0.8970 - val_accuracy: 0.6488
# Epoch 7/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8711 - accuracy: 0.6562 - val_loss: 0.8848 - val_accuracy: 0.6565
# Epoch 8/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8698 - accuracy: 0.6573 - val_loss: 0.8782 - val_accuracy: 0.6538
# Epoch 9/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8669 - accuracy: 0.6573 - val_loss: 0.8814 - val_accuracy: 0.6539
# Epoch 10/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.8647 - accuracy: 0.6574 - val_loss: 0.8754 - val_accuracy: 0.6577

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.plot(bs_hist2.history['loss'], color='red', label='Train-Loss')
plt.plot(bs_hist2.history['val_loss'], color='green', label='Val-Loss')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.plot(bs_hist2.history['accuracy'], color='red', label='Train-Accuracy')
plt.plot(bs_hist2.history['val_accuracy'], color='green', label='Val-Accuracy')
plt.legend(loc='best')
plt.show()

# %%
# Re-do the first experiment (question 2) considering the autoencoder dimensionality reduction
import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, (2, 2), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(8, (2, 2), activation='relu', padding='same')(x)
x = layers.Flatten()(x)
encoded = layers.Dense(2, activation='relu')(x)


x = layers.Dense(4, activation='relu')(encoded)
x = layers.Reshape((2, 2, 1))(x)
x = layers.Conv2D(16, (2, 2), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((7, 7))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder2 = keras.Model(input_img, decoded)
autoencoder2.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')

# %%
autoencoder2.fit(x_train, x_train,
                epochs=5,
                batch_size=256,
                shuffle=True,
                validation_data=(x_val, x_val))
# Out:
# Epoch 1/5
# 165/165 [==============================] - 83s 505ms/step - loss: 0.4610 - accuracy: 0.4810 - val_loss: 0.7171 - val_accuracy: 0.5026
# Epoch 2/5
# 165/165 [==============================] - 89s 539ms/step - loss: 0.4269 - accuracy: 0.4869 - val_loss: 0.5422 - val_accuracy: 0.5026
# Epoch 3/5
# 165/165 [==============================] - 88s 530ms/step - loss: 0.4181 - accuracy: 0.4914 - val_loss: 0.4348 - val_accuracy: 0.4966
# Epoch 4/5
# 165/165 [==============================] - 86s 523ms/step - loss: 0.4152 - accuracy: 0.4914 - val_loss: 0.4258 - val_accuracy: 0.4982
# Epoch 5/5
# 165/165 [==============================] - 86s 523ms/step - loss: 0.4131 - accuracy: 0.4916 - val_loss: 0.4130 - val_accuracy: 0.4921

# %%
decoded_imgs_train2 = autoencoder2.predict(x_train)
decoded_imgs_val2 = autoencoder2.predict(x_val)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_val[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs_val2[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1313/1313 [==============================] - 28s 21ms/step
# 563/563 [==============================] - 15s 27ms/step

# %%
bs_hist3 = bs_model.fit(decoded_imgs_train2, y_train, epochs=10,
                       validation_data = (decoded_imgs_val2, y_val))
# Out:
# Epoch 1/10
# 1313/1313 [==============================] - 56s 42ms/step - loss: 0.9966 - accuracy: 0.6179 - val_loss: 0.9791 - val_accuracy: 0.6298
# Epoch 2/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.9743 - accuracy: 0.6258 - val_loss: 0.9801 - val_accuracy: 0.6322
# Epoch 3/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.9685 - accuracy: 0.6282 - val_loss: 0.9676 - val_accuracy: 0.6350
# Epoch 4/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.9638 - accuracy: 0.6293 - val_loss: 0.9696 - val_accuracy: 0.6269
# Epoch 5/10
# 1313/1313 [==============================] - 41s 31ms/step - loss: 0.9613 - accuracy: 0.6302 - val_loss: 0.9703 - val_accuracy: 0.6301
# Epoch 6/10
# 1313/1313 [==============================] - 40s 30ms/step - loss: 0.9597 - accuracy: 0.6312 - val_loss: 0.9642 - val_accuracy: 0.6336
# Epoch 7/10
# 1313/1313 [==============================] - 40s 30ms/step - loss: 0.9573 - accuracy: 0.6313 - val_loss: 0.9638 - val_accuracy: 0.6323
# Epoch 8/10
# 1313/1313 [==============================] - 40s 30ms/step - loss: 0.9570 - accuracy: 0.6312 - val_loss: 0.9622 - val_accuracy: 0.6346
# Epoch 9/10
# 1313/1313 [==============================] - 40s 30ms/step - loss: 0.9547 - accuracy: 0.6322 - val_loss: 0.9602 - val_accuracy: 0.6362
# Epoch 10/10
# 1313/1313 [==============================] - 40s 30ms/step - loss: 0.9543 - accuracy: 0.6335 - val_loss: 0.9647 - val_accuracy: 0.6335

# %%
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.plot(bs_hist3.history['loss'], color='red', label='Train-Loss')
plt.plot(bs_hist3.history['val_loss'], color='green', label='Val-Loss')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.xlabel("Epochs", fontsize=18)
plt.ylabel('Accuracy', fontsize=18)
plt.plot(bs_hist3.history['accuracy'], color='red', label='Train-Accuracy')
plt.plot(bs_hist3.history['val_accuracy'], color='green', label='Val-Accuracy')
plt.legend(loc='best')
plt.show()

# %%
# What are the conclusions when using Autoencoders in this problem? Does accuracy improve?

# %% [markdown]
# **Comentários**: Foram escolhidas duas arquiteturas de autoenconder: A primeira mais complexa e a segunda mais simples. Em relação ao decodificação e ambas arquiteturas tiveram as metricas de avaliação muito parecidas, entretanto após a decodificaçação pela arquitetura mais complexa, é possivel observar melhor as imagens quando comparadas com as originais.
#
# Em relação ao desempenho na classificação com o uso dos autoencoders como parte do pré processamento, ambos os casos tiveram métricas de avaliação parecidas, em que a arquitetura mais complexa foi sutilmente melhor que a arquitetura menos complexa.
#
# Entretanto, os modelos considerados com autoencoders tiveram os piores desempenhos, de modo que as acurácias dos modelos cairam consideravelmente em relação ao baseline e aos modelos utilizando redução com análise de componentes principais.

# %% [markdown]
# #### Modelo final

# %%
x_train, y_train = train.loc[:, train.columns!='label'], train.loc[:, train.columns=='label']
x_test, y_test = test.loc[:, test.columns!='label'], test.loc[:, test.columns=='label']

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

x_train_values = x_train_scaled.reshape(-1, 28, 28, 1)
x_test_values = x_test_scaled.reshape(-1,28,28,1)

y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
bs_final = bs_model.fit(x_train_values, y_train, epochs=2)
# Out:
# Epoch 1/2
#    5/1875 [..............................] - ETA: 49s - loss: 0.1571 - accuracy: 0.9375
# C:\Users\bruno\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 1875/1875 [==============================] - 50s 26ms/step - loss: 0.2460 - accuracy: 0.9098
# Epoch 2/2
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.2221 - accuracy: 0.9182

# %%
bs_final.model.evaluate(x_test_values,y_test)
# Out:
#  11/313 [>.............................] - ETA: 3s - loss: 0.3393 - accuracy: 0.8722
# C:\Users\bruno\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 313/313 [==============================] - 4s 11ms/step - loss: 0.3009 - accuracy: 0.8955
# [0.30093011260032654, 0.8955000042915344]

# %% [markdown]
# **Comentários:** Após todos os testes realizados, o modelo final segue a arquitetura do baseline proposto inicialmente.
#
# No modelo **baseline** foi utilizado o otimizador Adam para se obter os parâmetros da rede neural convolucional (CNN), com inicialmente, 32 filtros com **kernel** $3 \times 3$, posteriormente, acrescentou-se um **Max Pooling** $2 \times 2$ . Por último, acrescentou-se mais 64 filtros com **kernel** $3 \times 3$ e, novamente, um max Pooling $2 \times 2$. Todas as funções de ativação utilizadas foram a ReLU, exceto na camada de **output**, a qual foi empregada a **Softmax**.
#
# O modelo foi retreinado no conjunto de dados de treino original (treino + validação) e aplicado o predict no conjunto de teste. E com esse modelo foi possivel obter uma acurácia de $0.8955$ no conjunto de teste.

# %% [markdown]
# ## Deadline
#
# Monday, November 18, 11:59 pm.
#
# Penalty policy for late submission: You are not encouraged to submit your assignment after due date. However, in case you do, your grade will be penalized as follows:
# - November 19, 11:59 pm : grade * 0.75
# - November 20, 11:59 pm : grade * 0.5
# - November 21, 11:59 pm : grade * 0.25

# %% [markdown]
# ## Submission
#
# On Google Classroom, submit your Jupyter Notebook (in Portuguese or English).
#
# **This activity is NOT individual, it must be done in pairs (two-person group).**
